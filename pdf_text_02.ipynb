# %%
PDF_PATH = '/Users/yamingdeng/Downloads/fintech/2020-02-20__山东益生种畜禽股份有限公司__002458__益生股份__2019年__年度报告.pdf'

# %%
from pdftext.extraction import plain_text_output
text = plain_text_output(PDF_PATH, sort=False, hyphens=False, page_range=[1,2,3]) # Optional arguments explained above

# %%
from pdftext.extraction import paginated_plain_text_output
textList = paginated_plain_text_output(PDF_PATH, page_range=[1,2,3], sort=False, hyphens=True)

# %%
textList
# Out:
# ['山东益生种畜禽股份有限公司 2019 年年度报告全文\n\n2\n\n第一节重要提示、目录和释义\n\n公司董事会、监事会及董事、监事、高级管理人员保证年度报告内容的真\n\n实、准确、完整，不存在虚假记载、误导性陈述或重大遗漏，并承担个别和连\n\n带的法律责任。\n\n公司负责人曹积生、主管会计工作负责人林杰及会计机构负责人(会计主管\n\n人员)徐淑艳声明：保证年度报告中财务报告的真实、准确、完整。\n\n所有董事均已出席了审议本报告的董事会会议。\n\n公司经本次董事会审议通过的利润分配预案为：以总股本 577,045,341 股为\n\n基数，向全体股东每 10 股派发现金红利 10.00 元（含税），送红股 0 股（含税），\n\n以资本公积金向全体股东每 10 股转增 7 股。',
# ...

# %%
from pdftext.extraction import dictionary_output
text_dict = dictionary_output(PDF_PATH, page_range=[1,2,3])

# %%
import json
with open('result.json', "w+") as f:
    f.write(json.dumps(text_dict))

# %%
import torch

# Check that MPS is available
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")

else:
    mps_device = torch.device("mps")

    # Create a Tensor directly on the mps device
    x = torch.ones(5, device=mps_device)
    # Or
    x = torch.ones(5, device="mps")

    # Any operation happens on the GPU
    y = x * 2

# %%
import pymupdf4llm
md_text = pymupdf4llm.to_markdown(PDF_PATH)
# Out:
# Processing /Users/yamingdeng/Downloads/fintech/2020-02-20__山东益生种畜禽股份有限公司__002458__益生股份__2019年__年度报告.pdf...
# ...

# %%
with open('result.md', 'w+') as f:
    f.write(md_text)
